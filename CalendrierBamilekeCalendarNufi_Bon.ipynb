# %% [markdown]
# <a href="https://colab.research.google.com/github/tchamna/Bamileke/blob/main/CalendrierBamilekeCalendarNufi_Bon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Author: Shck Ca᷅mnà' (Tchamna), Resulam, www.resulam.com

# %% [markdown]
# # Lié'nzɑ̄ pí Mɑ̄ŋū : Day and Month Definition

# %%
Language = "Nufi"

Days_Nufi = ["Líé'nkwè'","Nkɑ́ɑ́ntēē","Nzêngòò","Ncômntēē","Nzîngū","Nzîsō","Nsû'kwɑ̀","Nthʉ̄'ntāā"]

Month_Nufi = ["Ngù'fī","Nkùɑ̀nʉ̀ɑ̀","Mbàkngòfāt","Sò'njɑ̀ɑ̀","Njwēnɑ̌hntà'","Mòmòshʉ̄","Ntûmbhìngòfāt","Mɑ̂ngà'nshì",
              "Kùkū'", "Ndʉ̌'nzɑ̄","Nkhʉ̀ɑ̀nʉ̀ɑ̀","Ncátmɑ̄ŋū"]

Month_Eng = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

Month_Nufi_Eng = dict(zip(Month_Eng,Month_Nufi))

# %% [markdown]
# # Function Definition

# %%
import pandas as pd

def calendar_days(begin_nufi_day, year,month, max_day):

  """
  begin_nufi_day is one of the following days:

  "Líé'nkwè'",
  "Nkɑ́ɑ́ntēē",
  "Nzêngòò",
  "Ncômntēē",
  "Nzîngū",
  "Nzîsō",
  "Nsû'kwɑ̀",
  "Nthʉ̄'ntāā"

  """

  import calendar
  import pandas as pd

  from datetime import datetime

  beg_date_string = f"{year}-{month}-{1}"
  beg_day_of_week = datetime.strptime(beg_date_string, "%Y-%m-%d").strftime("%A")
  Month_str = datetime.strptime(beg_date_string, "%Y-%m-%d").strftime("%B")

  dict_day_num = {"Monday": 1, "Tuesday": 2, "Wednesday": 3, "Thursday": 4, "Friday": 5, "Saturday": 6, "Sunday": 7}
  start_day_num = dict_day_num[beg_day_of_week]
  # display the calendar
  # print(calendar.month(year, month))

  cal = calendar.monthcalendar(year, month)
  # print(*cal)
  days_int = [item for sublist in cal for item in sublist]
  days_list = []
  Days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
  Days_Nufi = ["Líé'nkwè'","Nkɑ́ɑ́ntēē","Nzêngòò","Ncômntēē","Nzîngū","Nzîsō","Nsû'kwɑ̀","Nthʉ̄'ntāā"]
  start_day_num_nufi = Days_Nufi.index(begin_nufi_day)

  days_int = [item for sublist in cal for item in sublist]
  days_list = []

  for n in range(0,max_day):

    temp = [f"{Month_str} {days_int[n+start_day_num-1]} {str(year)}", Days[(n+start_day_num-1)%7],Days_Nufi[(n+start_day_num_nufi)%8]]
    days_list.append(temp)
  # print(days_list)
  df = pd.DataFrame(days_list)
  df.columns = ["Date","Day(Eng)","Day(Nufi)"]
  return df

# %%
###############################################################################################
#                                                                                             #
##############################################################################################
# Days_Nufi = ["Líé'nkwè'","Nkɑ́ɑ́ntēē","Nzêngòò","Ncômntēē","Nzîngū","Nzîsō","Nsû'kwɑ̀","Nthʉ̄'ntāā"]
def calendar_nufi(df, next_month_index, year=2023, month=6, Number_of_days = 31):
  # Days_June = 30
  start_day_nufi = Days_Nufi[next_month_index]
  max_day = Number_of_days

  Date_df = calendar_days(start_day_nufi,year,month, max_day)
  df = pd.concat([df,Date_df],axis=0)

  next_month_index = (Number_of_days%8 + Days_Nufi.index(start_day_nufi))%8

  return df, next_month_index

# %%
def nufi_calendar_yearly(next_month_index, year = 2023, days_Feb=28):

  df = pd.DataFrame()

  # print(next_month_index)

  df, next_month_index = calendar_nufi(df, next_month_index, year=year,month=1, Number_of_days = 31)

  df, next_month_index = calendar_nufi(df, next_month_index, year=year,month=2,  Number_of_days = days_Feb)

  df, next_month_index = calendar_nufi(df, next_month_index, year=year,month=3, Number_of_days = 31)

  df, next_month_index = calendar_nufi(df, next_month_index, year=year,month=4, Number_of_days = 30)

  df, next_month_index = calendar_nufi(df, next_month_index, year=year,month=5, Number_of_days = 31)

  df, next_month_index = calendar_nufi(df, next_month_index, year=year,month=6, Number_of_days = 30)

  df, next_month_index = calendar_nufi(df, next_month_index, year=year,month=7, Number_of_days = 31)

  df, next_month_index = calendar_nufi(df, next_month_index, year=year,month=8, Number_of_days = 31)

  df, next_month_index = calendar_nufi(df, next_month_index, year=year,month=9, Number_of_days = 30)

  df, next_month_index = calendar_nufi(df, next_month_index, year=year,month=10, Number_of_days = 31)

  df, next_month_index = calendar_nufi(df, next_month_index, year=year,month=11, Number_of_days = 30)

  df, next_month_index = calendar_nufi(df, next_month_index, year=year,month=12, Number_of_days = 31)

  df.to_csv("Nufi_Calendar_2023.csv",encoding="utf 8 - sig")

  return df, next_month_index

# %%
# February 2023: 28 days (common year)
# February 2024: 29 days (leap year)
# February 2025: 28 days (common year)
# February 2026: 28 days (common year)
# February 2027: 28 days (common year)

def is_leap_year(year):
    return year % 4 == 0 and (year % 100 != 0 or year % 400 == 0)

# Example usage
year = 2023
if is_leap_year(year):
    print(f"{year} is a leap year.")
else:
    print(f"{year} is not a leap year.")
# Out:
# 2023 is not a leap year.

# %%
def calendar_nufi_many_years(Starting_year,End_year,month_index):

  import pandas as pd
  """
  This calendar will give you all the days in the year calendar_year
  And the calendar history from 2023 to calendar_year

  Days_Nufi = ["Líé'nkwè'","Nkɑ́ɑ́ntēē","Nzêngòò","Ncômntēē","Nzîngū","Nzîsō","Nsû'kwɑ̀","Nthʉ̄'ntāā"]

  """
  # Note: The initial date is what determine the remaining date!
  # You should know what date corresponds to, say, January 1, 2023
  # In my case, January 1, 2023 = Líé'nkwè', that is why Days_Nufi[0] = Líé'nkwè'
  # If for example, I am in 2025, and January 1, 2025 = Ncômntēē, then, I will pick
  # month_index = 3, because Days_Nufi[3] = Ncômntēē, and I will change the variable Starting_year to 2025

  # # INITIAL DATE
  # month_index = 0 # Days_Nufi[0] = "Líé'nkwè'"
  # Starting_year = 2023 # We are in 2023, the year of creation of this script

  # month_index = 3 # Days_Nufi[3] = "Ncômntēē"
  # Starting_year = 2025 #



  ddf = pd.DataFrame()
  for year in range(Starting_year,End_year+1):
    if is_leap_year(year):
      days_Feb_ = 29
    else:
      days_Feb_ = 28
    df, month_index = nufi_calendar_yearly(month_index, year = year,days_Feb=days_Feb_)
    ddf = pd.concat([ddf,df], axis=0)
  return df, ddf


# INITIAL DATE
month_index = 0 # Days_Nufi[0] = "Líé'nkwè'"
Starting_year = 2023 # We are in 2023, the year of creation of this script

# month_index = 3 # Days_Nufi[3] = "Ncômntēē"
# Starting_year = 2025 #


month_index = 3 # Days_Nufi[3] = "Ncômntēē"
Starting_year = 1900 #

#END YEAR
End_year = 2200

calendar_end_year, calendar_history = calendar_nufi_many_years(Starting_year,End_year,month_index)



calendar_history
# Out:
#                 Date   Day(Eng)   Day(Nufi)
# 0     January 1 1900     Monday    Ncômntēē
# 1     January 2 1900    Tuesday      Nzîngū
# 2     January 3 1900  Wednesday       Nzîsō
# 3     January 4 1900   Thursday    Nsû'kwɑ̀
# 4     January 5 1900     Friday  Nthʉ̄'ntāā
# ..               ...        ...         ...
# 26  December 27 2200   Saturday   Líé'nkwè'
# 27  December 28 2200     Sunday  Nkɑ́ɑ́ntēē
# 28  December 29 2200     Monday     Nzêngòò
# 29  December 30 2200    Tuesday    Ncômntēē
# 30  December 31 2200  Wednesday      Nzîngū
#
# [109938 rows x 3 columns]

# %%
def date_format_francais(date_str='January 1 1900'):

  from datetime import datetime
  # Parse the date
  date_obj = datetime.strptime(date_str, '%B %d %Y')

  # Reformat the date
  new_date_str = date_obj.strftime('%d-%m-%Y')

  return new_date_str

def date_yyyy_mm_dd(date_str='January 1 1900'):

  from datetime import datetime
  # Parse the date
  date_obj = datetime.strptime(date_str, '%B %d %Y')

  # Reformat the date
  new_date_str = date_obj.strftime('%Y %B %d')

  return new_date_str

calendar_history["Date (Jour-Mois-Annee)"] = calendar_history["Date"].apply(date_format_francais)
calendar_history["Date (yyyy-mm-dd)"] = calendar_history["Date"].apply(date_yyyy_mm_dd)

# %%
year = "1947|1981|2022"
month = "June|July"
day = "15|31"
# day = ""

mask = calendar_history["Date"].str.contains(year)
mask = mask & calendar_history["Date"].str.contains(month)
mask = mask & calendar_history["Date"].str.contains(day)

display(calendar_history[mask])
print("*"*55)
year = "2006"
month = "October"
day = "4"
# day = ""

mask = calendar_history["Date"] == "October 4 2006"
mask = mask | (calendar_history["Date"] == "October 1 1948" )
mask = mask | (calendar_history["Date"] == "June 15 1953")
mask = mask | (calendar_history["Date"] == "June 15 1981")
mask = mask | (calendar_history["Date"] == "March 31 1981")
mask = mask | (calendar_history["Date"] == "January 19 2016")


display(calendar_history[mask])
# Out:
#             Date   Day(Eng)   Day(Nufi) Date (Jour-Mois-Annee)  \
# 14  June 15 1947     Sunday    Nsû'kwɑ̀             15-06-1947
# 14  July 15 1947    Tuesday      Nzîngū             15-07-1947
# 30  July 31 1947   Thursday      Nzîngū             31-07-1947
# 14  June 15 1981     Monday  Nkɑ́ɑ́ntēē             15-06-1981
# 14  July 15 1981  Wednesday  Nthʉ̄'ntāā             15-07-1981
# 30  July 31 1981     Friday  Nthʉ̄'ntāā             31-07-1981
# 14  June 15 2022  Wednesday   Líé'nkwè'             15-06-2022
# 14  July 15 2022     Friday    Nsû'kwɑ̀             15-07-2022
# 30  July 31 2022     Sunday    Nsû'kwɑ̀             31-07-2022
#
#                             Nufi_Date  \
# 14       līē' 15, Mòmòshʉ̄, Ngù' 1947
# 14  līē' 15, Ntûmbhìngòfāt, Ngù' 1947
# 30  līē' 31, Ntûmbhìngòfāt, Ngù' 1947
# 14       līē' 15, Mòmòshʉ̄, Ngù' 1981
# 14  līē' 15, Ntûmbhìngòfāt, Ngù' 1981
# 30  līē' 31, Ntûmbhìngòfāt, Ngù' 1981
# 14       līē' 15, Mòmòshʉ̄, Ngù' 2022
# 14  līē' 15, Ntûmbhìngòfāt, Ngù' 2022
# 30  līē' 31, Ntûmbhìngòfāt, Ngù' 2022
#
#                                    Nufi_Full_Date Date (yyyy-mm-dd)
# 14         Nsû'kwɑ̀, līē' 15, Mòmòshʉ̄, Ngù' 1947      1947 June 15
# 14      Nzîngū, līē' 15, Ntûmbhìngòfāt, Ngù' 1947      1947 July 15
# 30      Nzîngū, līē' 31, Ntûmbhìngòfāt, Ngù' 1947      1947 July 31
# 14       Nkɑ́ɑ́ntēē, līē' 15, Mòmòshʉ̄, Ngù' 1981      1981 June 15
# 14  Nthʉ̄'ntāā, līē' 15, Ntûmbhìngòfāt, Ngù' 1981      1981 July 15
# 30  Nthʉ̄'ntāā, līē' 31, Ntûmbhìngòfāt, Ngù' 1981      1981 July 31
# 14        Líé'nkwè', līē' 15, Mòmòshʉ̄, Ngù' 2022      2022 June 15
# 14    Nsû'kwɑ̀, līē' 15, Ntûmbhìngòfāt, Ngù' 2022      2022 July 15
# 30    Nsû'kwɑ̀, līē' 31, Ntûmbhìngòfāt, Ngù' 2022      2022 July 31
# *******************************************************
#                Date   Day(Eng)   Day(Nufi) Date (Jour-Mois-Annee)  \
# 0    October 1 1948     Friday   Líé'nkwè'             01-10-1948
# 14     June 15 1953     Monday    Nsû'kwɑ̀             15-06-1953
# 30    March 31 1981    Tuesday       Nzîsō             31-03-1981
# 14     June 15 1981     Monday  Nkɑ́ɑ́ntēē             15-06-1981
# 3    October 4 2006  Wednesday    Ncômntēē             04-10-2006
# 18  January 19 2016    Tuesday       Nzîsō             19-01-2016
#
#                              Nufi_Date  \
# 0   Ntûmbhì līē', Ndʉ̌'nzɑ̄, Ngù' 1948
# 14        līē' 15, Mòmòshʉ̄, Ngù' 1953
# 30      līē' 31, Mbàkngòfāt, Ngù' 1981
# 14        līē' 15, Mòmòshʉ̄, Ngù' 1981
# 3         līē' 4, Ndʉ̌'nzɑ̄, Ngù' 2006
# 18          līē' 19, Ngù'fī, Ngù' 2016
#
#                                    Nufi_Full_Date Date (yyyy-mm-dd)
# 0   Líé'nkwè', Ntûmbhì līē', Ndʉ̌'nzɑ̄, Ngù' 1948   1948 October 01
# 14         Nsû'kwɑ̀, līē' 15, Mòmòshʉ̄, Ngù' 1953      1953 June 15
# 30          Nzîsō, līē' 31, Mbàkngòfāt, Ngù' 1981     1981 March 31
# 14       Nkɑ́ɑ́ntēē, līē' 15, Mòmòshʉ̄, Ngù' 1981      1981 June 15
# 3          Ncômntēē, līē' 4, Ndʉ̌'nzɑ̄, Ngù' 2006   2006 October 04
# 18              Nzîsō, līē' 19, Ngù'fī, Ngù' 2016   2016 January 19

# %%
def fromEng_toNufi_Date(x):

  Month = x.split(" ")[0]
  Day = x.split(" ")[1]
  Year = x.split(" ")[2]

  if int(Day) == 1:
      return f"Ntûmbhì līē', {Month_Nufi_Eng[Month]}, Ngù' {Year}"

  return f"līē' {Day}, {Month_Nufi_Eng[Month]}, Ngù' {Year}"

# %%
calendar_history["Nufi_Date"] = calendar_history["Date"].apply(fromEng_toNufi_Date)
calendar_history["Nufi_Full_Date"] = calendar_history["Day(Nufi)"] + ", " + calendar_history["Nufi_Date"]

calendar_history
# Out:
#                 Date   Day(Eng)   Day(Nufi) Date (Jour-Mois-Annee)  \
# 0     January 1 1900     Monday    Ncômntēē             01-01-1900
# 1     January 2 1900    Tuesday      Nzîngū             02-01-1900
# 2     January 3 1900  Wednesday       Nzîsō             03-01-1900
# 3     January 4 1900   Thursday    Nsû'kwɑ̀             04-01-1900
# 4     January 5 1900     Friday  Nthʉ̄'ntāā             05-01-1900
# ..               ...        ...         ...                    ...
# 26  December 27 2200   Saturday   Líé'nkwè'             27-12-2200
# 27  December 28 2200     Sunday  Nkɑ́ɑ́ntēē             28-12-2200
# 28  December 29 2200     Monday     Nzêngòò             29-12-2200
# 29  December 30 2200    Tuesday    Ncômntēē             30-12-2200
# 30  December 31 2200  Wednesday      Nzîngū             31-12-2200
#
#                           Nufi_Date  \
# 0   Ntûmbhì līē', Ngù'fī, Ngù' 1900
# 1         līē' 2, Ngù'fī, Ngù' 1900
# 2         līē' 3, Ngù'fī, Ngù' 1900
# 3         līē' 4, Ngù'fī, Ngù' 1900
# 4         līē' 5, Ngù'fī, Ngù' 1900
# ..                              ...
# 26    līē' 27, Ncátmɑ̄ŋū, Ngù' 2200
# 27    līē' 28, Ncátmɑ̄ŋū, Ngù' 2200
# 28    līē' 29, Ncátmɑ̄ŋū, Ngù' 2200
# 29    līē' 30, Ncátmɑ̄ŋū, Ngù' 2200
# 30    līē' 31, Ncátmɑ̄ŋū, Ngù' 2200
#
#                                Nufi_Full_Date Date (yyyy-mm-dd)
# 0   Ncômntēē, Ntûmbhì līē', Ngù'fī, Ngù' 1900   1900 January 01
# 1           Nzîngū, līē' 2, Ngù'fī, Ngù' 1900   1900 January 02
# 2            Nzîsō, līē' 3, Ngù'fī, Ngù' 1900   1900 January 03
# 3         Nsû'kwɑ̀, līē' 4, Ngù'fī, Ngù' 1900   1900 January 04
# 4       Nthʉ̄'ntāā, līē' 5, Ngù'fī, Ngù' 1900   1900 January 05
# ..                                        ...               ...
# 26   Líé'nkwè', līē' 27, Ncátmɑ̄ŋū, Ngù' 2200  2200 December 27
# 27  Nkɑ́ɑ́ntēē, līē' 28, Ncátmɑ̄ŋū, Ngù' 2200  2200 December 28
# 28     Nzêngòò, līē' 29, Ncátmɑ̄ŋū, Ngù' 2200  2200 December 29
# 29    Ncômntēē, līē' 30, Ncátmɑ̄ŋū, Ngù' 2200  2200 December 30
# 30      Nzîngū, līē' 31, Ncátmɑ̄ŋū, Ngù' 2200  2200 December 31
#
# [109938 rows x 7 columns]

# %% [markdown]
# # Today's Date in Nufi

# %%
import datetime, time

# Get the current date
now = datetime.datetime.now()

# Format the current date as a year-month-day string
Today = now.strftime("%B %d %Y")

mask_today = calendar_history["Date"] == Today

nufi_date_series = calendar_history[mask_today]["Nufi_Full_Date"]
eng_date_series = calendar_history[mask_today]["Day(Eng)"]

Today_day_nufi = "date introuvable" if len(nufi_date_series) ==0 else list(nufi_date_series)[0]
Today_day_Eng = "date introuvable" if len(eng_date_series) ==0 else list(eng_date_series)[0]

print("Zè'é mɑ́ " + Today_day_nufi)
time.sleep(4)
print("Yáá mɑ̀ lāhā ?" )
time.sleep(4)
print("Zēn zǎ mɑ́ Shck Ca᷅mnà' (Tchamna)" )
# Out:
# Zè'é mɑ́ Nzêngòò, līē' 29, Ncátmɑ̄ŋū, Ngù' 2023
# Yáá mɑ̀ lāhā ?
# Zēn zǎ mɑ́ Shck Ca᷅mnà' (Tchamna)

# %% [markdown]
# # Lǒ' Pɑ̌' yāā : Save as a CSV

# %%
year_start = calendar_history["Date (Jour-Mois-Annee)"].iloc[0].split("-")[-1]
year_end = calendar_history["Date (Jour-Mois-Annee)"].iloc[-1].split("-")[-1]

# %%
calendar_history.to_csv(f"Calendrier_{Language}_Calendar_{year_start}-{year_end}.csv",encoding="utf 8-sig")
